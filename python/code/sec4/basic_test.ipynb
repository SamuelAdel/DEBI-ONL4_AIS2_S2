# %%
x = 30
print('my age is:', x)
# Out:
# my age is: 30

# %%
print("my name is {0} and my age is {1}".format("samuel", 20))
# Out:
# my name is samuel and my age is 20

# %%
name = "samuel"
age = 20
course = "Machine Learning"
print(f"my name is {name}. and my age is {age}. Iam engaged in learning {course}.")
# Out:
# my name is samuel. and my age is 20. Iam engaged in learning Machine Learning.

# %%
x = "samuel"
type(x)

#print(type(x))
# Out:
# str

# %%
name = "depi learning"
Upper_text = name.upper()
print(Upper_text)
# Out:
# DEPI LEARNING

# %%
lower_text=Upper_text.lower()
lower_text
# Out:
# 'depi learning'

# %%
name.replace("depi","depi_ml")
# Out:
# 'depi_ml learning'

# %%
name = "depi learning for machine learning depi"
# name.count("depi")
x = name.split()

response = ' '.join(x)
response
response.startswith("depi")
# Out:
# True

# %%
print("welcome to depi \"machine learning course\"")
# Out:
# welcome to depi "machine learning course"

# %%
print("hello\tworld")
# Out:
# hello	world

# %%
X = 2
x = 20
print(hex(id(x)))
print(hex(id(X)))
# Out:
# 0x7ffd530a4608
# 0x7ffd530a43c8

# %%
x = ["depi",30,"python",True, ["ml","dl"],10.5 ]
print(type(x))
# Out:
# <class 'list'>

# %%
list_one=[1,2,3,4,"depi","learning",True,[1,2,3,4,["ml","dl","cv","nlp"]]]

# %%
list_one[7][4][0]
# Out:
# 'ml'

# %%
list_i = ["depi", "learning", "ml"]
list_i.append("dl")
list_i
# Out:
# ['depi', 'learning', 'ml', 'dl']

# %%
list_i.insert(0,"data")
list_i
# Out:
# ['data', 'depi', 'learning', 'ml', 'dl']

# %%
list_2 = [1,2,3]
list_3 = [4, 5, 6]
#list_2 + list_3
list_2.extend(list_3)
list_2
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list_new = ["depi", "learning", "python"]
list_new.remove("depi")
list_new
# Out:
# ['learning', 'python']

# %%
list_new.pop()
list_new
# Out:
# ['learning']

# %%
del list_new [0]
list_new
# Out:
# []

# %%
lst_1 = [1,2,3]
lst_2 = [4,5,6]
lst_3 = [7,8,9]
matrix = [lst_1,lst_2,lst_3]
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
my_list = ['one','two','three',4.6]
my_list*2
# Out:
# ['one', 'two', 'three', 4.6, 'one', 'two', 'three', 4.6]

# %%
name = input("enter your name: ")
name 
type(name)
# Out:
# str

# %%
name = input("enter your name")
id = input("enter your id")
print(f"my name is {name},my id is {id} ")
# Out:
# my name is samuel,my id is 2005

# %%
input_list = ["depi", "learning", "python"]
item = input("enter item in the list")
input_list.remove(item)
print(f"output list = {input_list}")
# Out:
# output list = ['learning', 'python']

# %%
my_list = [1,2,3,3]
index_val = my_list.index(3)
index_val
# Out:
# 2

# %%
my_list=[1,2,3,3]
index_val=my_list.count(3)
index_val
# Out:
# 2

# %%
list_sort = [3,1,5,7,9,2,0]
list_sort.sort()
list_sort
# Out:
# [0, 1, 2, 3, 5, 7, 9]

# %%
list_sort = [3,1,5,7,9,2,0]
list_sort.reverse()
list_sort
# Out:
# [0, 2, 9, 7, 5, 1, 3]

# %%
list_sort = [3,1,5,7,9,2,0]
list_sort.clear()
list_sort
# Out:
# []

# %%
tuple_1 = (1,2,3)

# %%
name = "depi"
tuple(name)
# Out:
# ('d', 'e', 'p', 'i')

# %%
set_1 = {"depi", "learning", "depi"}
set_1
#not duplicate
# Out:
# {'depi', 'learning'}

# %%
color = {"red", "green", "blue"}
color.remove("green")
print(color)
# Out:
# {'blue', 'red'}

# %%
a = {1,2,3}
b={3,4,5}
print(a.intersection(b))
# Out:
# {3}

# %%
a = {1,2,3}
b={3,4,5}
print(a.union(b))
# Out:
# {1, 2, 3, 4, 5}

# %%
dict_1 = {"key_1":25}
dict_1["key_1"]="depi"
dict_1
# Out:
# {'key_1': 'depi'}

# %%
5/2
# Out:
# 2.5

# %%
5//2
# Out:
# 2

# %%
5%2
# Out:
# 1

# %%
3!=4
# Out:
# True

# %%
num1=float(input("enter num1: "))
num2=float(input("enter num2: "))
print(f"sum : {num1 + num2}")
print(f"sub : {num1 - num2}")
print(f"mult : {num1 * num2}")
print(f"div : {num1 / num2}")
# Out:
# sum : 15.0
# sub : 5.0
# mult : 50.0
# div : 2.0

# %%
a = 200
b = 33
if b > a: 
    print("b is greater than a")
else: 
    print("b is not greater than a")
# Out:
# b is not greater than a

# %%
x = 5
y = 10
if x > 0 and y > 0 :
    print("positive numbers")
# Out:
# positive numbers

# %%
x = 5
result = "Even" if x % 2 == 0 else "odd"
print(result)
# Out:
# odd

# %%
a = 10 
b = 5
result = a + b if a > b else a - b
print(result)
# Out:
# 15

# %%
age = 21
print("adult") if age >= 18 else (print("teenager") if age >= 13 else print("child"))
# Out:
# adult

# %%
is_sunny = True
tem = 25

if is_sunny:
    print("sunny day")
    if tem > 20:
        print("warm")
    else:
        print("cool")
else:
    print("not sunny")
# Out:
# sunny day
# warm

# %%
grade = int (input("enter your grade"))

if 0<= grade <= 100:
    if 85 <= grade <= 100:
        print("A") 
    elif 75 <= grade <=  90:
        print("B")
    elif 65 <= grade <= 75:
        print("c")
    elif 50 <= grade <= 65:
        print("D")
    elif 0 <= grade <= 50:
        print("fail") 


else:
    print("enter value between 0-100")
# Out:
# A

# %%
x = 6
while x > 0:
    print("python")
    x -= 1
# Out:
# python
# python
# python
# python
# python
# python
