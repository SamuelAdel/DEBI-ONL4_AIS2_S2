# %%
""""
this class
"""
class StudentInfo:


    student_name = "Depi"
    student_age = 20
    Gpa = 3.2
    gender = "male"

    def student_info(self):

        print(self)

# %%
s1 = StudentInfo()
print(s1)
print(s1.student_info())
# Out:
# <__main__.StudentInfo object at 0x0000017D1EBDFC20>
# <__main__.StudentInfo object at 0x0000017D1EBDFC20>
# None

# %%
""""
this class
"""
class StudentInfo:


    def __init__(self, name = "test", age = 20):
        self.name = name
        self.age = age

    def student_info(self):

        return f" {self.name}, {self.age}"

# %%
s1 = StudentInfo("samuel", 20)
print(s1.student_info())
# Out:
#  samuel, 20

# %%
from abc import ABC , abstractmethod

class Animal(ABC):


    @abstractmethod
    def move(self):
        pass 

class Bird(Animal):

    def move(self):
        print("move from bird")

class Cat(Animal):

    def move(self):
        print("move from cat")

# %%
a = Bird()
a.move()
# Out:
# move from bird

# %%
a = Animal()
a.move()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 a = Animal()
#       2 a.move()
#
# TypeError: Can't instantiate abstract class Animal without an implementation for abstract method 'move'

# %%
from abc import ABC , abstractmethod

class Animal(ABC):


    @abstractmethod
    def move(self):
        pass 

class Bird(Animal):

    def move(self):
        pass

class Cat(Animal):

    def move(self):
        print("move from cat")

# %%
b = Bird()
b.move()

# %%
c = Cat()
c.move()
# Out:
# move from cat

# %%
from abc import ABC , abstractmethod

class Animal(ABC):


    @abstractmethod
    def move(self):
        pass 

class Bird(Animal):
    @abstractmethod
    def move(self):
        # print("move from cat") 
        pass

class Cat(Animal):

    def move(self):
        print("move from cat")

# %%
b = Bird()
b.move()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 b = Bird()
#       2 b.move()
#
# TypeError: Can't instantiate abstract class Bird without an implementation for abstract method 'move'

# %%
class A():
    def do_this(self):
        print("I am in A")

class B(A):
    pass 

class C():
    def do_this(self):
        print("I am in C")

class D(B,C): 
    pass

x = D()
x.do_this()
# Out:
# I am in A

# %%
class A():
    def do_this(self):
        print("I am in A")

class B(A):
    pass 

class C():
    def do_this(self):
        print("I am in C")

class D(C,B): 
    pass

x = D()
x.do_this()
# Out:
# I am in C
